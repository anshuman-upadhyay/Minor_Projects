# %%
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt

# %%
x,y = make_circles(n_samples=500,noise= 0.23,factor = 0.3,random_state= 53)

# %%
plt.figure(figsize=(6,6))
plt.scatter(
    x[:,0],
    x[:,1],
    c= y,
    cmap = "coolwarm",
    edgecolors= "k"
)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("make_Circle")
plt.show()

# %%
#prepare the train test split
from sklearn.model_selection import train_test_split as tts
x_train,x_test,y_train,y_test = tts(x,y,test_size=0.24,random_state=26)

# %%
x_train
# Out:
# array([[-0.07915427,  0.03136455],
#        [-0.15636513,  1.01971403],
#        [ 0.36725233,  0.07786057],
#        [-1.29834933,  0.06021506],
#        [-0.01251856, -1.6165062 ],
#        [ 0.42042682, -0.84689639],
#        [-0.26778561,  0.25726838],
#        [-0.9557459 ,  0.41151864],
#        [ 0.13615021, -1.31869727],
#        [ 0.31885218, -0.42710077],
#        [ 0.21017715, -0.1571052 ],
#        [ 0.28816972, -1.03282641],
#        [-0.20946786,  0.86870482],
#        [ 1.32487388, -0.35935708],
#        [ 0.06044028,  0.18577425],
#        [-0.46503723, -0.27539138],
#        [ 0.27923462, -0.15131851],
#        [-0.15210123,  0.77437683],
#        [-0.75062156, -0.69442612],
#        [-0.46914306,  0.126502  ],
#        [-1.22915362,  0.02097158],
#        [ 0.17788164, -0.42790891],
#        [ 0.91636448, -0.00649606],
#        [-0.78676792, -0.90314741],
#        [-0.6772292 ,  0.95241229],
#        [ 0.43644144, -0.75772738],
#        [ 0.40905129,  0.79499174],
# ...

# %%
from sklearn.svm import SVC
#make the model
model= SVC(kernel= "rbf",gamma = "scale")
model.fit(x_train,y_train)
print("Accuracy : ",model.score(x_test,y_test))
# Out:
# Accuracy :  0.9416666666666667

# %%
plt.scatter(x[:,0],x[:,1],c = y,cmap = "coolwarm")
plt.title("RBF Kernel Dataset")
plt.show()
