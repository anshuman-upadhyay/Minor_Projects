# %% [markdown]
# Applt BOW,TfIDf ,ngrams

# %%
import nltk
import numpy as np

# %%
# read the file Ass the file is not utf - 8 encodeded we change that
with open("Complete_data .txt","r",encoding="cp1252") as f:
    text = f.read()
print(text) 
with open("Complete_data .txt","w",encoding="utf-8") as f:
    f.write(text)
# Out:
# 0.1
# ...

# %%
# reread the file :
with open("Complete_data .txt","r",encoding="utf") as f:
    text = f.read()
print(text)
# Out:
# 0.1
# ...

# %% [markdown]
# Now Actually Work on it

# %%
import nltk

# %%
#Tokenisation
from nltk.tokenize import word_tokenize

sen = word_tokenize(text)
sen
# Out:
# ['0.1',
#  'ÃƒÆ',
#  '’',
#  'Ã‚Â¯Ãƒâ€šÃ‚Â¿Ãƒâ€šÃ‚Â½',
#  '1.The',
#  'Buddha',
#  ':',
#  '``',
#  'What',
#  'do',
#  'you',
#  'think',
#  ',',
#  'Rahula',
#  ':',
#  'What',
#  'is',
#  'a',
#  'mirror',
#  'for',
#  '?',
#  '``',
#  'The',
#  'Buddha',
#  ':',
#  'Rahula',
#  ':',
#  '``',
#  'For',
#  'reflection',
#  ',',
#  'sir',
#  '.',
#  '``',
#  'Rahula',
#  ':',
#  'The',
#  'Buddha',
#  ':',
#  '``',
#  'In',
#  'the',
#  'same',
#  'way',
#  ',',
#  'Rahula',
#  ',',
#  'bodily',
#  'acts',
#  ',',
#  'verbal',
#  'acts',
#  ',',
#  '&',
#  'mental',
#  'acts',
#  'are',
#  'to',
#  'be',
#  'done',
#  'with',
#  'repeated',
#  'reflection.The',
#  'Buddha',
#  ':',
#  "''",
#  'Whenever',
#  'you',
#  'want',
#  'to',
#  'perform',
#  'a',
#  'bodily',
#  'act',
#  ',',
#  'you',
#  'should',
#  'reflect',
#  'on',
#  'it',
#  ':',
#  "'This",
#  'bodily',
#  'act',
#  'I',
#  'want',
#  'to',
#  'perform',
#  'ÃƒÆ',
#  '’',
#  'Ã‚Â¯Ãƒâ€šÃ‚Â¿Ãƒâ€šÃ‚Â½',
#  'would',
# ...

# %%
#convert to lower case clean the sentence by cleaning
sen = [word.lower() for word in sen]
sen = [word for word in  sen if word.isalpha()]
sen
# Out:
# ['ãƒæ',
#  'buddha',
#  'what',
#  'do',
#  'you',
#  'think',
#  'rahula',
#  'what',
#  'is',
#  'a',
#  'mirror',
#  'for',
#  'the',
#  'buddha',
#  'rahula',
#  'for',
#  'reflection',
#  'sir',
#  'rahula',
#  'the',
#  'buddha',
#  'in',
#  'the',
#  'same',
#  'way',
#  'rahula',
#  'bodily',
#  'acts',
#  'verbal',
#  'acts',
#  'mental',
#  'acts',
#  'are',
#  'to',
#  'be',
#  'done',
#  'with',
#  'repeated',
#  'buddha',
#  'whenever',
#  'you',
#  'want',
#  'to',
#  'perform',
#  'a',
#  'bodily',
#  'act',
#  'you',
#  'should',
#  'reflect',
#  'on',
#  'it',
#  'bodily',
#  'act',
#  'i',
#  'want',
#  'to',
#  'perform',
#  'ãƒæ',
#  'would',
#  'it',
#  'lead',
#  'to',
#  'to',
#  'the',
#  'affliction',
#  'of',
#  'others',
#  'or',
#  'to',
#  'both',
#  'is',
#  'it',
#  'an',
#  'unskillful',
#  'bodily',
#  'act',
#  'with',
#  'painful',
#  'consequences',
#  'painful',
#  'results',
#  'if',
#  'on',
#  'reflection',
#  'you',
#  'know',
#  'that',
# ...

# %%
#Stop Word
from nltk.corpus import stopwords
nltk.download("stopwords") 
nltk.download("wordnet") 

# get the stopwords
stop_words = set(stopwords.words("english"))

#get all the other important words
filter_word = [
    word for word in sen if word not in stop_words
]
print(filter_word)
# Out:
# ['ãƒæ', 'buddha', 'think', 'rahula', 'mirror', 'buddha', 'rahula', 'reflection', 'sir', 'rahula', 'buddha', 'way', 'rahula', 'bodily', 'acts', 'verbal', 'acts', 'mental', 'acts', 'done', 'repeated', 'buddha', 'whenever', 'want', 'perform', 'bodily', 'act', 'reflect', 'bodily', 'act', 'want', 'perform', 'ãƒæ', 'would', 'lead', 'affliction', 'others', 'unskillful', 'bodily', 'act', 'painful', 'consequences', 'painful', 'results', 'reflection', 'know', 'would', 'lead', 'affliction', 'others', 'would', 'unskillful', 'bodily', 'act', 'painful', 'consequences', 'painful', 'results', 'bodily', 'act', 'sort', 'absolutely', 'unfit', 'reflection', 'know', 'would', 'cause', 'affliction', 'would', 'skillful', 'bodily', 'act', 'happy', 'consequences', 'happy', 'results', 'bodily', 'act', 'sort', 'fit', 'similarly', 'verbal', 'acts', 'mental', 'acts', 'performing', 'bodily', 'act', 'reflect', 'bodily', 'act', 'ãƒæ', 'leading', 'affliction', 'others', 'unskillful', 'bodily', 'act', 'painful', 'cons
# ...

# %%
# Stemming
from nltk.stem import PorterStemmer
nltk.download("punkt")
nltk.download("punkt_tab")

setmmer = PorterStemmer()
for word in filter_word:
    print(setmmer.stem(word),end=" ")
# Out:
# [nltk_data] Downloading package punkt to /home/anshuman/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/anshuman/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# ...

# %%
#lemmatize the words
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

lemmatized = [
    lemmatizer.lemmatize(word) for word in filter_word
] 
print(lemmatized)
# Out:
# ['ãƒæ', 'buddha', 'think', 'rahula', 'mirror', 'buddha', 'rahula', 'reflection', 'sir', 'rahula', 'buddha', 'way', 'rahula', 'bodily', 'act', 'verbal', 'act', 'mental', 'act', 'done', 'repeated', 'buddha', 'whenever', 'want', 'perform', 'bodily', 'act', 'reflect', 'bodily', 'act', 'want', 'perform', 'ãƒæ', 'would', 'lead', 'affliction', 'others', 'unskillful', 'bodily', 'act', 'painful', 'consequence', 'painful', 'result', 'reflection', 'know', 'would', 'lead', 'affliction', 'others', 'would', 'unskillful', 'bodily', 'act', 'painful', 'consequence', 'painful', 'result', 'bodily', 'act', 'sort', 'absolutely', 'unfit', 'reflection', 'know', 'would', 'cause', 'affliction', 'would', 'skillful', 'bodily', 'act', 'happy', 'consequence', 'happy', 'result', 'bodily', 'act', 'sort', 'fit', 'similarly', 'verbal', 'act', 'mental', 'act', 'performing', 'bodily', 'act', 'reflect', 'bodily', 'act', 'ãƒæ', 'leading', 'affliction', 'others', 'unskillful', 'bodily', 'act', 'painful', 'consequence', '
# ...

# %% [markdown]
# Implement the OnehotEncoder

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder()
#encoder requires a   2d array and not string array
wording = [[word] for word in lemmatized]
encoded = encoder.fit_transform(wording)
arr = encoded.toarray()

# %%
for i,vec in enumerate(arr):
    print(f"{lemmatized[i]} : {vec}")
# Out:
# ãƒæ : [0. 0. 0. ... 0. 0. 1.]
# buddha : [0. 0. 0. ... 0. 0. 0.]
# think : [0. 0. 0. ... 0. 0. 0.]
# rahula : [0. 0. 0. ... 0. 0. 0.]
# mirror : [0. 0. 0. ... 0. 0. 0.]
# buddha : [0. 0. 0. ... 0. 0. 0.]
# rahula : [0. 0. 0. ... 0. 0. 0.]
# reflection : [0. 0. 0. ... 0. 0. 0.]
# sir : [0. 0. 0. ... 0. 0. 0.]
# rahula : [0. 0. 0. ... 0. 0. 0.]
# buddha : [0. 0. 0. ... 0. 0. 0.]
# way : [0. 0. 0. ... 0. 0. 0.]
# rahula : [0. 0. 0. ... 0. 0. 0.]
# bodily : [0. 0. 0. ... 0. 0. 0.]
# act : [0. 0. 0. ... 0. 0. 0.]
# verbal : [0. 0. 0. ... 0. 0. 0.]
# act : [0. 0. 0. ... 0. 0. 0.]
# mental : [0. 0. 0. ... 0. 0. 0.]
# act : [0. 0. 0. ... 0. 0. 0.]
# done : [0. 0. 0. ... 0. 0. 0.]
# repeated : [0. 0. 0. ... 0. 0. 0.]
# buddha : [0. 0. 0. ... 0. 0. 0.]
# whenever : [0. 0. 0. ... 0. 0. 0.]
# want : [0. 0. 0. ... 0. 0. 0.]
# perform : [0. 0. 0. ... 0. 0. 0.]
# bodily : [0. 0. 0. ... 0. 0. 0.]
# act : [0. 0. 0. ... 0. 0. 0.]
# reflect : [0. 0. 0. ... 0. 0. 0.]
# bodily : [0. 0. 0. ... 0. 0. 0.]
# ...

# %% [markdown]
# Using Bag of words

# %%
#import the Bag of Words
from sklearn.feature_extraction.text import CountVectorizer
cv= CountVectorizer(ngram_range=(1,3))

# %%
#apply bag of words on lemmatized
corpus = [" ".join(lemmatized)]
X = cv.fit_transform(corpus)
cv.vocabulary_
# Out:
# {'ãƒæ': 110622,
#  'buddha': 9801,
#  'think': 95059,
#  'rahula': 73604,
#  'mirror': 59712,
#  'reflection': 74763,
#  'sir': 85468,
#  'way': 104396,
#  'bodily': 8068,
#  'act': 910,
#  'verbal': 102704,
#  'mental': 58396,
#  'done': 21894,
#  'repeated': 75763,
#  'whenever': 105378,
#  'want': 103851,
#  'perform': 67887,
#  'reflect': 74732,
#  'would': 109596,
#  'lead': 49554,
#  'affliction': 1519,
#  'others': 65603,
#  'unskillful': 101318,
#  'painful': 66251,
#  'consequence': 14839,
#  'result': 76454,
#  'know': 47732,
#  'sort': 86772,
#  'absolutely': 446,
#  'unfit': 100781,
#  'cause': 10942,
#  'skillful': 85698,
#  'happy': 39049,
#  'fit': 30951,
#  'similarly': 84804,
#  'performing': 67921,
#  'leading': 49641,
#  'give': 34951,
#  'may': 57026,
#  'continue': 15279,
#  'performed': 67907,
#  'led': 49933,
#  'confess': 14211,
#  'reveal': 76660,
#  'lay': 49494,
#  'open': 65177,
#  'teacher': 92576,
#  'knowledgeable': 48626,
#  'companion': 13552,
# ...

# %%
arr = [X[i].toarray() for i in range(X.shape[0]) ]

# %%
#get embedding
for i,vec in enumerate(arr):
    print(f"{lemmatized[i]} : {vec}")
# Out:
# ãƒæ : [[0.00183234 0.00036647 0.00036647 ... 0.00036647 0.00036647 0.00036647]]

# %% [markdown]
# 3 . Now Implementing TFIDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
cv = TfidfVectorizer(ngram_range=(1,3))

# %%
#convert the broken words back into a single text 
corpus = [" ".join(lemmatized)]

X = cv.fit_transform(corpus)

# %%
cv.vocabulary_
# Out:
# {'ãƒæ': 110622,
#  'buddha': 9801,
#  'think': 95059,
#  'rahula': 73604,
#  'mirror': 59712,
#  'reflection': 74763,
#  'sir': 85468,
#  'way': 104396,
#  'bodily': 8068,
#  'act': 910,
#  'verbal': 102704,
#  'mental': 58396,
#  'done': 21894,
#  'repeated': 75763,
#  'whenever': 105378,
#  'want': 103851,
#  'perform': 67887,
#  'reflect': 74732,
#  'would': 109596,
#  'lead': 49554,
#  'affliction': 1519,
#  'others': 65603,
#  'unskillful': 101318,
#  'painful': 66251,
#  'consequence': 14839,
#  'result': 76454,
#  'know': 47732,
#  'sort': 86772,
#  'absolutely': 446,
#  'unfit': 100781,
#  'cause': 10942,
#  'skillful': 85698,
#  'happy': 39049,
#  'fit': 30951,
#  'similarly': 84804,
#  'performing': 67921,
#  'leading': 49641,
#  'give': 34951,
#  'may': 57026,
#  'continue': 15279,
#  'performed': 67907,
#  'led': 49933,
#  'confess': 14211,
#  'reveal': 76660,
#  'lay': 49494,
#  'open': 65177,
#  'teacher': 92576,
#  'knowledgeable': 48626,
#  'companion': 13552,
# ...

# %%
arr = [X[i].toarray() for i in range(X.shape[0]) ]

# %%
for i,vec in enumerate(arr):
    print(f"{lemmatized[i]} : {vec}")
# Out:
# ãƒæ : [[0. 0. 0. ... 0. 0. 1.]]
# buddha : [[0. 0. 0. ... 0. 0. 0.]]
# think : [[0. 0. 0. ... 0. 0. 0.]]
# rahula : [[0. 0. 0. ... 0. 0. 0.]]
# mirror : [[0. 0. 0. ... 0. 0. 0.]]
# buddha : [[0. 0. 0. ... 0. 0. 0.]]
# rahula : [[0. 0. 0. ... 0. 0. 0.]]
# reflection : [[0. 0. 0. ... 0. 0. 0.]]
# sir : [[0. 0. 0. ... 0. 0. 0.]]
# rahula : [[0. 0. 0. ... 0. 0. 0.]]
# buddha : [[0. 0. 0. ... 0. 0. 0.]]
# way : [[0. 0. 0. ... 0. 0. 0.]]
# rahula : [[0. 0. 0. ... 0. 0. 0.]]
# bodily : [[0. 0. 0. ... 0. 0. 0.]]
# act : [[0. 0. 0. ... 0. 0. 0.]]
# verbal : [[0. 0. 0. ... 0. 0. 0.]]
# act : [[0. 0. 0. ... 0. 0. 0.]]
# mental : [[0. 0. 0. ... 0. 0. 0.]]
# act : [[0. 0. 0. ... 0. 0. 0.]]
# done : [[0. 0. 0. ... 0. 0. 0.]]
# repeated : [[0. 0. 0. ... 0. 0. 0.]]
# buddha : [[0. 0. 0. ... 0. 0. 0.]]
# whenever : [[0. 0. 0. ... 0. 0. 0.]]
# want : [[0. 0. 0. ... 0. 0. 0.]]
# perform : [[0. 0. 0. ... 0. 0. 0.]]
# bodily : [[0. 0. 0. ... 0. 0. 0.]]
# act : [[0. 0. 0. ... 0. 0. 0.]]
# ...
